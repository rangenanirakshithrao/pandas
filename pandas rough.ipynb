# %%
#IMPORTING A CSV FILE THROUGH PANDAS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('ScoreFinal.csv')
df
# Out:
#       Score  Age  Subject  Sex   ID
# 0      88.0   18    Maths    1    1
# 1      85.0   19    Maths    1    2
# 2      45.0   19    Maths    1    3
# 3      82.0   18    Maths    1    4
# 4      82.0   18    Maths    2    5
# ...     ...  ...      ...  ...  ...
# 1792   41.0   19  Physics    2  595
# 1793   71.0   18  Physics    1  596
# 1794   49.0   20  Physics    1  597
# 1795   71.0   20  Physics    1  598
# 1796   69.0   19  Physics    1  599
#
# [1797 rows x 5 columns]

# %%
#SELECTING A COLUMN
df['Subject']
# Out:
# 0         Maths
# 1         Maths
# 2         Maths
# 3         Maths
# 4         Maths
#          ...
# 1792    Physics
# 1793    Physics
# 1794    Physics
# 1795    Physics
# 1796    Physics
# Name: Subject, Length: 1797, dtype: object

# %%
#df.set_index('Subject')

# %%
#SETS THE REQUIRED COLUMN AS INDEX
#df.set_index('Subject',inplace=True)

# %%
df
# Out:
#       Score  Age  Subject  Sex   ID
# 0      88.0   18    Maths    1    1
# 1      85.0   19    Maths    1    2
# 2      45.0   19    Maths    1    3
# 3      82.0   18    Maths    1    4
# 4      82.0   18    Maths    2    5
# ...     ...  ...      ...  ...  ...
# 1792   41.0   19  Physics    2  595
# 1793   71.0   18  Physics    1  596
# 1794   49.0   20  Physics    1  597
# 1795   71.0   20  Physics    1  598
# 1796   69.0   19  Physics    1  599
#
# [1797 rows x 5 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1797, step=1)

# %%
#FILTERING THE DATA
filt=(df['Score']==82)

# %%
df[filt]
# Out:
#       Score  Age        Subject  Sex   ID
# 3      82.0   18          Maths    1    4
# 4      82.0   18          Maths    2    5
# 15     82.0   20          Maths    1   16
# 20     82.0   18          Maths    1   21
# 44     82.0   20          Maths    2   45
# ...     ...  ...            ...  ...  ...
# 1132   82.0   21  Data Structue    1  534
# 1146   82.0   18  Data Structue    1  548
# 1187   82.0   19  Data Structue    1  589
# 1190   82.0   19  Data Structue    1  592
# 1192   82.0   19  Data Structue    1  594
#
# [114 rows x 5 columns]

# %%
filt=(df['Score']==82) & (df['Age']==18)

# %%
df[filt]
# Out:
#       Score  Age        Subject  Sex   ID
# 3      82.0   18          Maths    1    4
# 4      82.0   18          Maths    2    5
# 20     82.0   18          Maths    1   21
# 47     82.0   18          Maths    1   48
# 50     82.0   18          Maths    1   51
# 63     82.0   18          Maths    1   64
# 74     82.0   18          Maths    2   75
# 104    82.0   18          Maths    2  105
# 140    82.0   18          Maths    1  141
# 162    82.0   18          Maths    1  163
# 189    82.0   18          Maths    2  190
# 204    82.0   18          Maths    2  205
# 217    82.0   18          Maths    1  218
# 222    82.0   18          Maths    1  223
# 238    82.0   18          Maths    1  239
# 313    82.0   18          Maths    1  314
# 355    82.0   18          Maths    1  356
# 371    82.0   18          Maths    1  372
# 409    82.0   18          Maths    2  410
# 410    82.0   18          Maths    1  411
# 433    82.0   18          Maths    1  434
# ...

# %%
#FILTERING MULTIPLE COLUMNS

filt=(df['Score']==82) & (df['Subject']=='Maths') & (df['Age']==18) & (df['Sex']==1)

# %%
df[filt]
# Out:
#      Score  Age Subject  Sex   ID
# 3     82.0   18   Maths    1    4
# 20    82.0   18   Maths    1   21
# 47    82.0   18   Maths    1   48
# 50    82.0   18   Maths    1   51
# 63    82.0   18   Maths    1   64
# 140   82.0   18   Maths    1  141
# 162   82.0   18   Maths    1  163
# 217   82.0   18   Maths    1  218
# 222   82.0   18   Maths    1  223
# 238   82.0   18   Maths    1  239
# 313   82.0   18   Maths    1  314
# 355   82.0   18   Maths    1  356
# 371   82.0   18   Maths    1  372
# 410   82.0   18   Maths    1  411
# 433   82.0   18   Maths    1  434
# 451   82.0   18   Maths    1  452
# 470   82.0   18   Maths    1  471
# 516   82.0   18   Maths    1  517
# 536   82.0   18   Maths    1  537
# 542   82.0   18   Maths    1  543
# 550   82.0   18   Maths    1  551
# 555   82.0   18   Maths    1  556
# 578   82.0   18   Maths    1  579

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('ScoreFinal.csv')
df
# Out:
#       Score  Age  Subject  Sex   ID
# 0      88.0   18    Maths    1    1
# 1      85.0   19    Maths    1    2
# 2      45.0   19    Maths    1    3
# 3      82.0   18    Maths    1    4
# 4      82.0   18    Maths    2    5
# ...     ...  ...      ...  ...  ...
# 1792   41.0   19  Physics    2  595
# 1793   71.0   18  Physics    1  596
# 1794   49.0   20  Physics    1  597
# 1795   71.0   20  Physics    1  598
# 1796   69.0   19  Physics    1  599
#
# [1797 rows x 5 columns]

# %%
#  Apply method(). Works for both DF's and Series. 


df['Subject'].apply(len)
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 1792    7
# 1793    7
# 1794    7
# 1795    7
# 1796    7
# Name: Subject, Length: 1797, dtype: int64

# %%
df.apply(np.sum, axis=0)
# Out:
# Score                                                 126582
# Age                                                    34362
# Subject    MathsMathsMathsMathsMathsMathsMathsMathsMathsM...
# Sex                                                     2154
# ID                                                    539100
# dtype: object

# %%
 df.apply(lambda x: [1, 2], axis=1)
# Out:
# 0       [1, 2]
# 1       [1, 2]
# 2       [1, 2]
# 3       [1, 2]
# 4       [1, 2]
#          ...
# 1792    [1, 2]
# 1793    [1, 2]
# 1794    [1, 2]
# 1795    [1, 2]
# 1796    [1, 2]
# Length: 1797, dtype: object

# %%
def update_Subject(Subject):
    return Subject.upper()

# %%
df['Subject'].apply(update_Subject)
# Out:
# 0         MATHS
# 1         MATHS
# 2         MATHS
# 3         MATHS
# 4         MATHS
#          ...
# 1792    PHYSICS
# 1793    PHYSICS
# 1794    PHYSICS
# 1795    PHYSICS
# 1796    PHYSICS
# Name: Subject, Length: 1797, dtype: object

# %%
df['Subject']=df['Subject'].apply(update_Subject)

# %%
df
# Out:
#       Score  Age  Subject  Sex   ID
# 0      88.0   18    MATHS    1    1
# 1      85.0   19    MATHS    1    2
# 2      45.0   19    MATHS    1    3
# 3      82.0   18    MATHS    1    4
# 4      82.0   18    MATHS    2    5
# ...     ...  ...      ...  ...  ...
# 1792   41.0   19  PHYSICS    2  595
# 1793   71.0   18  PHYSICS    1  596
# 1794   49.0   20  PHYSICS    1  597
# 1795   71.0   20  PHYSICS    1  598
# 1796   69.0   19  PHYSICS    1  599
#
# [1797 rows x 5 columns]

# %%
 df['Subject']=df['Subject'].apply(lambda x:x.lower())

# %%
df
# Out:
#       Score  Age  Subject  Sex   ID
# 0      88.0   18    maths    1    1
# 1      85.0   19    maths    1    2
# 2      45.0   19    maths    1    3
# 3      82.0   18    maths    1    4
# 4      82.0   18    maths    2    5
# ...     ...  ...      ...  ...  ...
# 1792   41.0   19  physics    2  595
# 1793   71.0   18  physics    1  596
# 1794   49.0   20  physics    1  597
# 1795   71.0   20  physics    1  598
# 1796   69.0   19  physics    1  599
#
# [1797 rows x 5 columns]

# %%
df.apply(len)
# Out:
# Score      1797
# Age        1797
# Subject    1797
# Sex        1797
# ID         1797
# dtype: int64

# %%
min(df['Score'])
# Out:
# 0.0

# %%
df.apply(pd.Series.min)
# Out:
# Score                  0
# Age                   18
# Subject    data structue
# Sex                    1
# ID                     1
# dtype: object

# %%
df.apply(lambda x:x.max())
# Out:
# Score           95
# Age             21
# Subject    physics
# Sex              2
# ID             599
# dtype: object

# %%
A=df[['ID','Age']]
A.apply(lambda x:np.sqrt(x))
# Out:
#              ID       Age
# 0      1.000000  4.242641
# 1      1.414214  4.358899
# 2      1.732051  4.358899
# 3      2.000000  4.242641
# 4      2.236068  4.242641
# ...         ...       ...
# 1792  24.392622  4.358899
# 1793  24.413111  4.242641
# 1794  24.433583  4.472136
# 1795  24.454039  4.472136
# 1796  24.474477  4.358899
#
# [1797 rows x 2 columns]

# %%
#applymap method applies for each element in a dataframe,where as it cannot work for series objects.

df.applymap(lambda x: x*2)
# Out:
#       Score  Age         Subject  Sex    ID
# 0     176.0   36      mathsmaths    2     2
# 1     170.0   38      mathsmaths    2     4
# 2      90.0   38      mathsmaths    2     6
# 3     164.0   36      mathsmaths    2     8
# 4     164.0   36      mathsmaths    4    10
# ...     ...  ...             ...  ...   ...
# 1792   82.0   38  physicsphysics    4  1190
# 1793  142.0   36  physicsphysics    2  1192
# 1794   98.0   40  physicsphysics    2  1194
# 1795  142.0   40  physicsphysics    2  1196
# 1796  138.0   38  physicsphysics    2  1198
#
# [1797 rows x 5 columns]

# %%
df['ID'].applymap(lambda x: x*2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-29970be7dec3> in <module>
# ----> 1 df['ID'].applymap(lambda x: x*2)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'applymap'

# %%
# MAP is only used to perform functions on a series but not on a dataframes.

df['Subject'].map(len)
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 1792    7
# 1793    7
# 1794    7
# 1795    7
# 1796    7
# Name: Subject, Length: 1797, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('ScoreFinal.csv')

# %%
# MAP replaces a particular element in a column and prints Nan when the map is not given


df['Subject']=df['Subject'].map({'Maths':'Python','Physics':'Java'})

# %%
df
# Out:
#       Score  Age Subject  Sex   ID
# 0      88.0   18  Python    1    1
# 1      85.0   19  Python    1    2
# 2      45.0   19  Python    1    3
# 3      82.0   18  Python    1    4
# 4      82.0   18  Python    2    5
# ...     ...  ...     ...  ...  ...
# 1792   41.0   19    Java    2  595
# 1793   71.0   18    Java    1  596
# 1794   49.0   20    Java    1  597
# 1795   71.0   20    Java    1  598
# 1796   69.0   19    Java    1  599
#
# [1797 rows x 5 columns]

# %%
df.iloc[1135]
# Out:
# Score       76
# Age         18
# Subject    NaN
# Sex          1
# ID         537
# Name: 1135, dtype: object

# %%
# REPLACE FUNCTION: it replaces the entire column and doesn't show up Nan instead replaces the old values.

df['Subject']=df['Subject'].replace({'Data Structue':'C','Physics':'Java'})

# %%
df
# Out:
#       Score  Age Subject  Sex   ID
# 0      88.0   18  Python    1    1
# 1      85.0   19  Python    1    2
# 2      45.0   19  Python    1    3
# 3      82.0   18  Python    1    4
# 4      82.0   18  Python    2    5
# ...     ...  ...     ...  ...  ...
# 1792   41.0   19    Java    2  595
# 1793   71.0   18    Java    1  596
# 1794   49.0   20    Java    1  597
# 1795   71.0   20    Java    1  598
# 1796   69.0   19    Java    1  599
#
# [1797 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('ScoreFinal.csv')

# %%
df['Subject']=df['Subject'].replace({'Physics':'Java'})

# %%
df
# Out:
#       Score  Age Subject  Sex   ID
# 0      88.0   18   Maths    1    1
# 1      85.0   19   Maths    1    2
# 2      45.0   19   Maths    1    3
# 3      82.0   18   Maths    1    4
# 4      82.0   18   Maths    2    5
# ...     ...  ...     ...  ...  ...
# 1792   41.0   19    Java    2  595
# 1793   71.0   18    Java    1  596
# 1794   49.0   20    Java    1  597
# 1795   71.0   20    Java    1  598
# 1796   69.0   19    Java    1  599
#
# [1797 rows x 5 columns]

# %%
df.iloc[1135]
# Out:
# Score                 76
# Age                   18
# Subject    Data Structue
# Sex                    1
# ID                   537
# Name: 1135, dtype: object

# %%
# RENAME function renames the column names.

df.rename(columns={'Score':'Marks'})
# Out:
#       Marks  Age Subject  Sex   ID
# 0      88.0   18   Maths    1    1
# 1      85.0   19   Maths    1    2
# 2      45.0   19   Maths    1    3
# 3      82.0   18   Maths    1    4
# 4      82.0   18   Maths    2    5
# ...     ...  ...     ...  ...  ...
# 1792   41.0   19    Java    2  595
# 1793   71.0   18    Java    1  596
# 1794   49.0   20    Java    1  597
# 1795   71.0   20    Java    1  598
# 1796   69.0   19    Java    1  599
#
# [1797 rows x 5 columns]

# %%
df['Marks']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Marks'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-ed523570dd66> in <module>
# ----> 1 df['Marks']
#
# ...

# %%
df.rename(columns={'Score':'Marks'},inplace=True)

# %%
df['Marks']=df.rename(columns={'Score':'Marks'})

# %%
df
# Out:
#      Marks  Age Subject  Sex   ID
# 0       88   18   Maths    1    1
# 1       85   19   Maths    1    2
# 2       45   19   Maths    1    3
# 3       82   18   Maths    1    4
# 4       82   18   Maths    2    5
# ...    ...  ...     ...  ...  ...
# 1792    41   19    Java    2  595
# 1793    71   18    Java    1  596
# 1794    49   20    Java    1  597
# 1795    71   20    Java    1  598
# 1796    69   19    Java    1  599
#
# [1797 rows x 5 columns]

# %%
df['Sex']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 1792    2
# 1793    1
# 1794    1
# 1795    1
# 1796    1
# Name: Sex, Length: 1797, dtype: int64

# %%
df['Sex'].map({1:'Male',2:'Female'})
# Out:
# 0         Male
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 1792    Female
# 1793      Male
# 1794      Male
# 1795      Male
# 1796      Male
# Name: Sex, Length: 1797, dtype: object

# %%
df['Sex']=df['Sex'].map({1:'Male',2:'Female'})

# %%
df
# Out:
#      Marks  Age Subject     Sex   ID
# 0       88   18   Maths    Male    1
# 1       85   19   Maths    Male    2
# 2       45   19   Maths    Male    3
# 3       82   18   Maths    Male    4
# 4       82   18   Maths  Female    5
# ...    ...  ...     ...     ...  ...
# 1792    41   19    Java  Female  595
# 1793    71   18    Java    Male  596
# 1794    49   20    Java    Male  597
# 1795    71   20    Java    Male  598
# 1796    69   19    Java    Male  599
#
# [1797 rows x 5 columns]

# %%
#ADDITION & DELETION/REMOVING OF COLUMNS

# %%
df['SS']=df['Subject']+ ' ' +df['Sex']

# %%
df
# Out:
#      Marks  Age Subject     Sex   ID            SS
# 0       88   18   Maths    Male    1    Maths Male
# 1       85   19   Maths    Male    2    Maths Male
# 2       45   19   Maths    Male    3    Maths Male
# 3       82   18   Maths    Male    4    Maths Male
# 4       82   18   Maths  Female    5  Maths Female
# ...    ...  ...     ...     ...  ...           ...
# 1792    41   19    Java  Female  595   Java Female
# 1793    71   18    Java    Male  596     Java Male
# 1794    49   20    Java    Male  597     Java Male
# 1795    71   20    Java    Male  598     Java Male
# 1796    69   19    Java    Male  599     Java Male
#
# [1797 rows x 6 columns]

# %%
df.drop(columns=['Age','ID'])
# Out:
#      Marks Subject     Sex            SS
# 0       88   Maths    Male    Maths Male
# 1       85   Maths    Male    Maths Male
# 2       45   Maths    Male    Maths Male
# 3       82   Maths    Male    Maths Male
# 4       82   Maths  Female  Maths Female
# ...    ...     ...     ...           ...
# 1792    41    Java  Female   Java Female
# 1793    71    Java    Male     Java Male
# 1794    49    Java    Male     Java Male
# 1795    71    Java    Male     Java Male
# 1796    69    Java    Male     Java Male
#
# [1797 rows x 4 columns]

# %%
df['SS'].str.split(' ')
# Out:
# 0         [Maths, Male]
# 1         [Maths, Male]
# 2         [Maths, Male]
# 3         [Maths, Male]
# 4       [Maths, Female]
#              ...
# 1792     [Java, Female]
# 1793       [Java, Male]
# 1794       [Java, Male]
# 1795       [Java, Male]
# 1796       [Java, Male]
# Name: SS, Length: 1797, dtype: object

# %%
df["SS"].str.split(' ',expand=True)
# Out:
#           0       1     2
# 0     Maths    Male  None
# 1     Maths    Male  None
# 2     Maths    Male  None
# 3     Maths    Male  None
# 4     Maths  Female  None
# ...     ...     ...   ...
# 1792   Java  Female  None
# 1793   Java    Male  None
# 1794   Java    Male  None
# 1795   Java    Male  None
# 1796   Java    Male  None
#
# [1797 rows x 3 columns]

# %%
df[['Subject','Sex','nan']]=df['SS'].str.split(' ',expand=True)

# %%
df
# Out:
#      Marks  Age Subject     Sex   ID            SS   nan
# 0       88   18   Maths    Male    1    Maths Male  None
# 1       85   19   Maths    Male    2    Maths Male  None
# 2       45   19   Maths    Male    3    Maths Male  None
# 3       82   18   Maths    Male    4    Maths Male  None
# 4       82   18   Maths  Female    5  Maths Female  None
# ...    ...  ...     ...     ...  ...           ...   ...
# 1792    41   19    Java  Female  595   Java Female  None
# 1793    71   18    Java    Male  596     Java Male  None
# 1794    49   20    Java    Male  597     Java Male  None
# 1795    71   20    Java    Male  598     Java Male  None
# 1796    69   19    Java    Male  599     Java Male  None
#
# [1797 rows x 7 columns]

# %%
#ADDITION & DELETION/REMOVING OF ROWS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('ScoreFinal.csv')

# %%
df.append({'Marks':100,'Age':23,'Subject':'Python'},ignore_index=True)
# Out:
#       Score  Age  Subject  Sex     ID  Marks
# 0      88.0   18    Maths  1.0    1.0    NaN
# 1      85.0   19    Maths  1.0    2.0    NaN
# 2      45.0   19    Maths  1.0    3.0    NaN
# 3      82.0   18    Maths  1.0    4.0    NaN
# 4      82.0   18    Maths  2.0    5.0    NaN
# ...     ...  ...      ...  ...    ...    ...
# 1793   71.0   18  Physics  1.0  596.0    NaN
# 1794   49.0   20  Physics  1.0  597.0    NaN
# 1795   71.0   20  Physics  1.0  598.0    NaN
# 1796   69.0   19  Physics  1.0  599.0    NaN
# 1797    NaN   23   Python  NaN    NaN  100.0
#
# [1798 rows x 6 columns]

# %%
import pandas as pd

A=({'Score':[95],'Sex':'Female','Score':[98],'Sex':'Male'})
df2=pd.DataFrame(A)
df2
# Out:
#    Score   Sex
# 0     98  Male

# %%
df.append(df2,ignore_index=True)
# Out:
#       Score   Age  Subject   Sex     ID
# 0      88.0  18.0    Maths     1    1.0
# 1      85.0  19.0    Maths     1    2.0
# 2      45.0  19.0    Maths     1    3.0
# 3      82.0  18.0    Maths     1    4.0
# 4      82.0  18.0    Maths     2    5.0
# ...     ...   ...      ...   ...    ...
# 1793   71.0  18.0  Physics     1  596.0
# 1794   49.0  20.0  Physics     1  597.0
# 1795   71.0  20.0  Physics     1  598.0
# 1796   69.0  19.0  Physics     1  599.0
# 1797   98.0   NaN      NaN  Male    NaN
#
# [1798 rows x 5 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('ScoreFinal.csv')

# %%
#SORTING ROWS & COLUMNS


df.sort_values(by='Score')
# Out:
#       Score  Age        Subject  Sex   ID
# 738     0.0   21  Data Structue    2  140
# 1197    0.0   19  Data Structue    1  599
# 1319    0.0   18        Physics    1  122
# 1288    0.0   19        Physics    1   91
# 1063    0.0   21  Data Structue    2  465
# ...     ...  ...            ...  ...  ...
# 187    95.0   20          Maths    1  188
# 430    95.0   20          Maths    1  431
# 414    95.0   18          Maths    2  415
# 102    95.0   18          Maths    1  103
# 478    95.0   18          Maths    1  479
#
# [1797 rows x 5 columns]

# %%
df.sort_values(by='Score',ascending=False)
# Out:
#       Score  Age        Subject  Sex   ID
# 219    95.0   18          Maths    2  220
# 486    95.0   20          Maths    1  487
# 395    95.0   20          Maths    1  396
# 345    95.0   20          Maths    1  346
# 59     95.0   18          Maths    2   60
# ...     ...  ...            ...  ...  ...
# 1063    0.0   21  Data Structue    2  465
# 814     0.0   19  Data Structue    1  216
# 1319    0.0   18        Physics    1  122
# 1263    0.0   21        Physics    1   66
# 685     0.0   19  Data Structue    1   87
#
# [1797 rows x 5 columns]

# %%
df.sort_values(by=['Score','ID'],ascending=False)
# Out:
#       Score  Age        Subject  Sex   ID
# 583    95.0   18          Maths    1  584
# 580    95.0   18          Maths    1  581
# 568    95.0   20          Maths    1  569
# 559    95.0   20          Maths    2  560
# 541    95.0   18          Maths    1  542
# ...     ...  ...            ...  ...  ...
# 685     0.0   19  Data Structue    1   87
# 1263    0.0   21        Physics    1   66
# 52      0.0   19          Maths    1   53
# 632     0.0   18  Data Structue    1   34
# 1214    0.0   18        Physics    1   17
#
# [1797 rows x 5 columns]

# %%
df.sort_values(by=['Score','ID'],ascending=[False,True])
# Out:
#       Score  Age        Subject  Sex   ID
# 5      95.0   20          Maths    1    6
# 6      95.0   18          Maths    1    7
# 17     95.0   18          Maths    1   18
# 41     95.0   20          Maths    1   42
# 53     95.0   20          Maths    1   54
# ...     ...  ...            ...  ...  ...
# 391     0.0   20          Maths    1  392
# 1016    0.0   19  Data Structue    1  418
# 1063    0.0   21  Data Structue    2  465
# 564     0.0   21          Maths    2  565
# 1197    0.0   19  Data Structue    1  599
#
# [1797 rows x 5 columns]

# %%
df.sort_index()
# Out:
#       Score  Age  Subject  Sex   ID
# 0      88.0   18    Maths    1    1
# 1      85.0   19    Maths    1    2
# 2      45.0   19    Maths    1    3
# 3      82.0   18    Maths    1    4
# 4      82.0   18    Maths    2    5
# ...     ...  ...      ...  ...  ...
# 1792   41.0   19  Physics    2  595
# 1793   71.0   18  Physics    1  596
# 1794   49.0   20  Physics    1  597
# 1795   71.0   20  Physics    1  598
# 1796   69.0   19  Physics    1  599
#
# [1797 rows x 5 columns]

# %%
df[['Subject','Score']]
# Out:
#       Subject  Score
# 0       Maths   88.0
# 1       Maths   85.0
# 2       Maths   45.0
# 3       Maths   82.0
# 4       Maths   82.0
# ...       ...    ...
# 1792  Physics   41.0
# 1793  Physics   71.0
# 1794  Physics   49.0
# 1795  Physics   71.0
# 1796  Physics   69.0
#
# [1797 rows x 2 columns]

# %%
df.sort_values(by='Subject',inplace=True)

# %%
df[['Subject','Score']].head(50)
# Out:
#            Subject  Score
# 898  Data Structue   85.0
# 802  Data Structue   79.0
# 801  Data Structue   39.0
# 800  Data Structue   85.0
# 799  Data Structue   60.0
# 798  Data Structue   47.0
# 797  Data Structue   82.0
# 803  Data Structue   76.0
# 796  Data Structue   89.0
# 794  Data Structue   85.0
# 793  Data Structue   85.0
# 792  Data Structue   79.0
# 791  Data Structue   79.0
# 790  Data Structue   85.0
# 789  Data Structue   79.0
# 795  Data Structue   79.0
# 804  Data Structue   60.0
# 805  Data Structue   69.0
# 806  Data Structue   69.0
# 821  Data Structue   76.0
# 820  Data Structue   79.0
# 819  Data Structue   60.0
# 818  Data Structue   89.0
# 817  Data Structue   39.0
# 816  Data Structue   76.0
# 815  Data Structue   76.0
# 814  Data Structue    0.0
# 813  Data Structue   60.0
# 812  Data Structue   69.0
# 811  Data Structue   82.0
# 810  Data Structue   82.0
# 809  Data Structue   60.0
# 808  Data Structue   60.0
# 807  Data Structue   89.0
# ...

# %%
df['Score'].nlargest(10)
# Out:
# 197    95.0
# 219    95.0
# 208    95.0
# 187    95.0
# 150    95.0
# 184    95.0
# 180    95.0
# 179    95.0
# 175    95.0
# 225    95.0
# Name: Score, dtype: float64

# %%
df.nlargest(10,['Score'])
# Out:
#      Score  Age Subject  Sex   ID
# 197   95.0   20   Maths    1  198
# 219   95.0   18   Maths    2  220
# 208   95.0   18   Maths    1  209
# 187   95.0   20   Maths    1  188
# 150   95.0   18   Maths    1  151
# 184   95.0   20   Maths    2  185
# 180   95.0   20   Maths    1  181
# 179   95.0   18   Maths    2  180
# 175   95.0   18   Maths    1  176
# 225   95.0   20   Maths    1  226

# %%
df.nsmallest(10,['Score'])
# Out:
#       Score  Age        Subject  Sex   ID
# 814     0.0   19  Data Structue    1  216
# 760     0.0   18  Data Structue    1  162
# 632     0.0   18  Data Structue    1   34
# 738     0.0   21  Data Structue    2  140
# 685     0.0   19  Data Structue    1   87
# 1063    0.0   21  Data Structue    2  465
# 1197    0.0   19  Data Structue    1  599
# 1016    0.0   19  Data Structue    1  418
# 52      0.0   19          Maths    1   53
# 564     0.0   21          Maths    2  565

# %%
# GROUPING & AGGREGATIONS



df=pd.read_csv('HollywoodMovies.csv')

# %%
df
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
df['WorldGross'].median()
# Out:
# 88.18

# %%
df.median()
# Out:
# RottenTomatoes        52.000
# AudienceScore         61.000
# TheatersOpenWeek    2798.000
# OpeningWeekend        13.150
# BOAvgOpenWeekend    5983.000
# DomesticGross         40.415
# ForeignGross          46.655
# WorldGross            88.180
# Budget                35.000
# Profitability        254.820
# OpenProfit            34.610
# Year                2010.000
# dtype: float64

# %%
df.mean()
# Out:
# RottenTomatoes        51.707558
# AudienceScore         61.271224
# TheatersOpenWeek    2495.246575
# OpeningWeekend        20.620826
# BOAvgOpenWeekend    8562.593651
# DomesticGross         68.162544
# ForeignGross         101.237419
# WorldGross           169.009945
# Budget                56.117168
# Profitability        384.620100
# OpenProfit            62.223575
# Year                2010.236082
# dtype: float64

# %%
df.describe()
# Out:
#        RottenTomatoes  AudienceScore  TheatersOpenWeek  OpeningWeekend  \
# count      913.000000     907.000000        949.000000      969.000000
# mean        51.707558      61.271224       2495.246575       20.620826
# std         26.821268      16.602457       1164.223356       25.338689
# min          0.000000      19.000000          1.000000        0.010000
# 25%         28.000000      49.000000       2054.000000        5.300000
# 50%         52.000000      61.000000       2798.000000       13.150000
# 75%         75.000000      74.000000       3285.000000       26.200000
# max         99.000000      96.000000       4468.000000      207.440000
#
#        BOAvgOpenWeekend  DomesticGross  ForeignGross   WorldGross      Budget  \
# count        945.000000     970.000000    876.000000   914.000000  897.000000
# mean        8562.593651      68.162544    101.237419   169.009945   56.117168
# std        10645.135565      80.409969    155.987696   227.744380   53.755914
# ...

# %%
df['Genre'].count()
# Out:
# 691

# %%
df['Genre'].value_counts()
# Out:
# Comedy         177
# Action         166
# Drama          109
# Horror          52
# Animation       51
# Thriller        35
# Adventure       30
# Romance         20
# Crime           15
# Biography       14
# Documentary      7
# Fantasy          6
# Mystery          5
# Musical          4
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts(ascending=True)
# Out:
# Musical          4
# Mystery          5
# Fantasy          6
# Documentary      7
# Biography       14
# Crime           15
# Romance         20
# Adventure       30
# Thriller        35
# Animation       51
# Horror          52
# Drama          109
# Action         166
# Comedy         177
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts(normalize=True,ascending=True)
# Out:
# Musical        0.005789
# Mystery        0.007236
# Fantasy        0.008683
# Documentary    0.010130
# Biography      0.020260
# Crime          0.021708
# Romance        0.028944
# Adventure      0.043415
# Thriller       0.050651
# Animation      0.073806
# Horror         0.075253
# Drama          0.157742
# Action         0.240232
# Comedy         0.256151
# Name: Genre, dtype: float64

# %%
grp=df.groupby(['Genre'])

# %%
grp.get_group('Action')
# Out:
#                                         Movie   LeadStudio  RottenTomatoes  \
# 0                                Spider-Man 3         Sony            61.0
# 2                                Transformers    Paramount            57.0
# 3    Pirates of the Caribbean: At World's End       Disney            45.0
# 9                                         300  Warner Bros            60.0
# 15                                Rush Hour 3  Warner Bros            20.0
# ..                                        ...          ...             ...
# 823                                Iron Man 3  Buena Vista            78.0
# 825                        THG: Catching Fire    Lionsgate            90.0
# 828                          Fast & Furious 6    Universal            69.0
# 831                              Man of Steel  Warner Bros            55.0
# 886     The Mortal Instruments: City of Bones         Sony            12.0
#
# ...

# %%
df.groupby(['Genre']).get_group('Adventure')
# Out:
#                                                  Movie   LeadStudio  \
# 4            Harry Potter and the Order of the Phoenix  Warner Bros
# 44                                        3:10 to Yuma    Lionsgate
# 58                                            Stardust    Paramount
# 120                                        10,000 B.C.  Warner Bros
# 121                            Beverly Hills Chihuahua       Disney
# 135                                        Fool's Gold  Warner Bros
# 148                                       Nim's Island  Independent
# 149                                          Australia          Fox
# 151                                  College Road Trip  Buena Vista
# 164        Harold and Kumar Escape from Guantanamo Bay  Warner Bros
# 221                                          Meet Dave          Fox
# 231                                          Sex Drive       Summit
# 235                                      City of Ember  Independent
# ...

# %%
grp['Movie'].value_counts().head(50)
# Out:
# Genre   Movie
# Action  12 Rounds                                    1
#         2012                                         1
#         300                                          1
#         Abduction                                    1
#         Appaloosa                                    1
#         Armored                                      1
#         Avatar                                       1
#         Babylon A.D.                                 1
#         Bangkok Dangerous                            1
#         Battle: Los Angeles                          1
#         Beowulf                                      1
#         Body of Lies                                 1
#         Brooklyn's Finest                            1
#         Captain America: The First Avenger           1
#         Cats & Dogs: The Revenge of Kitty Galore     1
#         Cirque du Freak: The Vampire's Assistant     1
#         Clash of the Titans                          1
# ...

# %%
grp['Movie'].value_counts().loc['Biography']
# Out:
# Movie
# Cadillac Records        1
# Charlie Wilson's War    1
# Conviction              1
# Invictus                1
# Julie & Julia           1
# Lovelace                1
# Milk                    1
# Notorious               1
# Public Enemies          1
# The Blind Side          1
# The Express             1
# The King's Speech       1
# The Runaways            1
# The Social Network      1
# Name: Movie, dtype: int64

# %%
grp['OpeningWeekend'].median()
# Out:
# Genre
# Action         20.90
# Adventure      14.00
# Animation      34.08
# Biography       6.58
# Comedy         12.22
# Crime          16.30
# Documentary     3.41
# Drama           7.33
# Fantasy        15.70
# Horror         14.10
# Musical        18.17
# Mystery        11.60
# Romance        12.37
# Thriller       14.81
# Name: OpeningWeekend, dtype: float64

# %%
grp['OpeningWeekend'].median().loc['Mystery']
# Out:
# 11.6

# %%
grp['OpeningWeekend'].agg(['median','mean'])
# Out:
#              median       mean
# Genre
# Action        20.90  32.443554
# Adventure     14.00  26.085667
# Animation     34.08  35.569216
# Biography      6.58  11.204286
# Comedy        12.22  15.524192
# Crime         16.30  15.732667
# Documentary    3.41  12.134286
# Drama          7.33  10.757780
# Fantasy       15.70  39.525000
# Horror        14.10  16.829804
# Musical       18.17  18.285000
# Mystery       11.60  15.580000
# Romance       12.37  20.901000
# Thriller      14.81  24.254000

# %%
grp['OpeningWeekend'].apply(lambda x: x>=60)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 965      NaN
# 966      NaN
# 967      NaN
# 968      NaN
# 969    False
# Name: OpeningWeekend, Length: 970, dtype: object

# %%
# CASTING DATATYPES & HANDLING MISSING VALUES

# %%
df
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
df.dropna()
# Out:
#                                          Movie     LeadStudio  RottenTomatoes  \
# 0                                 Spider-Man 3           Sony            61.0
# 1                              Shrek the Third      Paramount            42.0
# 2                                 Transformers      Paramount            57.0
# 3     Pirates of the Caribbean: At World's End         Disney            45.0
# 4    Harry Potter and the Order of the Phoenix    Warner Bros            78.0
# ..                                         ...            ...             ...
# 648                         What's Your Number            Fox            24.0
# 649                            Winnie The Pooh         Disney            91.0
# 650                         X-Men: First Class         Disney            87.0
# 651                              Your Highness      Universal            26.0
# 652                                  Zookeeper  Happy Madison            14.0
#
# ...

# %%
df.dropna(axis='index',how='any')
# Out:
#                                          Movie     LeadStudio  RottenTomatoes  \
# 0                                 Spider-Man 3           Sony            61.0
# 1                              Shrek the Third      Paramount            42.0
# 2                                 Transformers      Paramount            57.0
# 3     Pirates of the Caribbean: At World's End         Disney            45.0
# 4    Harry Potter and the Order of the Phoenix    Warner Bros            78.0
# ..                                         ...            ...             ...
# 648                         What's Your Number            Fox            24.0
# 649                            Winnie The Pooh         Disney            91.0
# 650                         X-Men: First Class         Disney            87.0
# 651                              Your Highness      Universal            26.0
# 652                                  Zookeeper  Happy Madison            14.0
#
# ...

# %%
# WHEN HOW = ALL IS GIVEN AS INPUT IT ONLY DELETS THE ROW IF ENTIRE ROW HAS NAN VALUES.


df.dropna(axis='index',how='all')
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#      RottenTomatoes  AudienceScore          Story      Genre  \
# ...

# %%
df.dropna(axis=1,how='any')
# Out:
#                                          Movie  DomesticGross  Year
# 0                                 Spider-Man 3         336.53  2007
# 1                              Shrek the Third         322.72  2007
# 2                                 Transformers         319.25  2007
# 3     Pirates of the Caribbean: At World's End         309.42  2007
# 4    Harry Potter and the Order of the Phoenix         292.00  2007
# ..                                         ...            ...   ...
# 965                                The Canyons           0.06  2013
# 966                                   The Call          51.87  2013
# 967                        The English Teacher           0.10  2013
# 968                       John Dies at the End           0.14  2013
# 969                                   Lovelace           0.36  2013
#
# [970 rows x 3 columns]

# %%
# IS() FUNCTION HELPS IN GIVING US THE BOOLEAN VALUES


df.isna()
# Out:
#      Movie  LeadStudio  RottenTomatoes  AudienceScore  Story  Genre  \
# 0    False       False           False          False  False  False
# 1    False       False           False          False  False  False
# 2    False       False           False          False  False  False
# 3    False       False           False          False  False  False
# 4    False       False           False          False  False  False
# ..     ...         ...             ...            ...    ...    ...
# 965  False       False           False           True   True   True
# 966  False       False           False          False   True   True
# 967  False       False           False           True   True   True
# 968  False       False           False          False   True   True
# 969  False       False           False          False   True  False
#
#      TheatersOpenWeek  OpeningWeekend  BOAvgOpenWeekend  DomesticGross  \
# 0               False           False             False          False
# ...

# %%
# FILLS THE MISSING VALUES WITH GIVEN PARAMETERS.

df.fillna('..|..')
# Out:
#                                          Movie              LeadStudio  \
# 0                                 Spider-Man 3                    Sony
# 1                              Shrek the Third               Paramount
# 2                                 Transformers               Paramount
# 3     Pirates of the Caribbean: At World's End                  Disney
# 4    Harry Potter and the Order of the Phoenix             Warner Bros
# ..                                         ...                     ...
# 965                                The Canyons                     IFC
# 966                                   The Call                 TriStar
# 967                        The English Teacher  Cinedigm Entertainment
# 968                       John Dies at the End                Magnolia
# 969                                   Lovelace              Radius-TWC
#
#     RottenTomatoes AudienceScore          Story      Genre TheatersOpenWeek  \
# ...

# %%
df.dtypes
# Out:
# Movie                object
# LeadStudio           object
# RottenTomatoes      float64
# AudienceScore       float64
# Story                object
# Genre                object
# TheatersOpenWeek    float64
# OpeningWeekend      float64
# BOAvgOpenWeekend    float64
# DomesticGross       float64
# ForeignGross        float64
# WorldGross          float64
# Budget              float64
# Profitability       float64
# OpenProfit          float64
# Year                  int64
# dtype: object
